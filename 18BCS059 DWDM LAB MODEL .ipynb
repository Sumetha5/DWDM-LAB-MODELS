# %% [markdown]
# Apriori Algorithm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from apyori import apriori

# %%
data = pd.read_csv('retail_dataset.csv')
data
# Out:
#           0       1       2       3       4       5       6
# 0     Bread    Wine    Eggs    Meat  Cheese  Pencil  Diaper
# 1     Bread  Cheese    Meat  Diaper    Wine    Milk  Pencil
# 2    Cheese    Meat    Eggs    Milk    Wine     NaN     NaN
# 3    Cheese    Meat    Eggs    Milk    Wine     NaN     NaN
# 4      Meat  Pencil    Wine     NaN     NaN     NaN     NaN
# ..      ...     ...     ...     ...     ...     ...     ...
# 310   Bread    Eggs  Cheese     NaN     NaN     NaN     NaN
# 311    Meat    Milk  Pencil     NaN     NaN     NaN     NaN
# 312   Bread  Cheese    Eggs    Meat  Pencil  Diaper    Wine
# 313    Meat  Cheese     NaN     NaN     NaN     NaN     NaN
# 314    Eggs    Wine   Bagel   Bread    Meat     NaN     NaN
#
# [315 rows x 7 columns]

# %%
data.shape
# Out:
# (315, 7)

# %%
data.describe()
# Out:
#             0      1     2     3     4       5      6
# count     315    285   245   187   133      71     41
# unique      9      9     9     9     9       9      9
# top     Bread  Bagel  Eggs  Milk  Wine  Pencil  Bread
# freq       74     47    52    45    36      13     11

# %%
records = []
for i in range(0,315):
    records.append([str(data.values[i,j]) for j in range(0,7)])

# %%
for sets in records:
    print(sets)
# Out:
# ['Bread', 'Wine', 'Eggs', 'Meat', 'Cheese', 'Pencil', 'Diaper']
# ['Bread', 'Cheese', 'Meat', 'Diaper', 'Wine', 'Milk', 'Pencil']
# ['Cheese', 'Meat', 'Eggs', 'Milk', 'Wine', 'nan', 'nan']
# ['Cheese', 'Meat', 'Eggs', 'Milk', 'Wine', 'nan', 'nan']
# ['Meat', 'Pencil', 'Wine', 'nan', 'nan', 'nan', 'nan']
# ['Eggs', 'Bread', 'Wine', 'Pencil', 'Milk', 'Diaper', 'Bagel']
# ['Wine', 'Pencil', 'Eggs', 'Cheese', 'nan', 'nan', 'nan']
# ['Bagel', 'Bread', 'Milk', 'Pencil', 'Diaper', 'nan', 'nan']
# ['Bread', 'Diaper', 'Cheese', 'Milk', 'Wine', 'Eggs', 'nan']
# ['Bagel', 'Wine', 'Diaper', 'Meat', 'Pencil', 'Eggs', 'Cheese']
# ['Cheese', 'Meat', 'Eggs', 'Milk', 'Wine', 'nan', 'nan']
# ['Bagel', 'Eggs', 'Meat', 'Bread', 'Diaper', 'Wine', 'Milk']
# ['Bread', 'Diaper', 'Pencil', 'Bagel', 'Meat', 'nan', 'nan']
# ['Bagel', 'Cheese', 'Milk', 'Meat', 'nan', 'nan', 'nan']
# ['Bread', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['Pencil', 'Diaper', 'Bagel', 'nan', 'nan', 'nan', 'nan']
# ...

# %%
association_rules = apriori(records, min_support = 0.005, min_confidence = 0.7, min_lift = 1, min_length = 2)

# %%
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 184

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'nan'}), support=0.8698412698412699, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.8698412698412699, lift=1.0)])

# %%
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    print("Rule :"+ str(item[0]) + "->" + str(item[1]))
    print("Support : {}".format(item[1]))
    print("Confidence : {}".format(item[2][0][2]))
    print("Lift : {}".format(item[2][0][3]))
    print("\n------------------------------------------------\n")
# Out:
# Rule :frozenset({'nan'})->0.8698412698412699
# Support : 0.8698412698412699
# Confidence : 0.8698412698412699
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'Milk', 'Bagel', 'Bread'})->0.17142857142857143
# Support : 0.17142857142857143
# Confidence : 0.7605633802816901
# Lift : 1.5067765081052351
#
# ------------------------------------------------
#
# Rule :frozenset({'Milk', 'Diaper', 'Bread'})->0.11428571428571428
# Support : 0.11428571428571428
# Confidence : 0.7346938775510203
# Lift : 1.4555256064690025
#
# ------------------------------------------------
#
# Rule :frozenset({'Meat', 'Eggs', 'Cheese'})->0.21587301587301588
# Support : 0.21587301587301588
# Confidence : 0.723404255319149
# Lift : 1.5191489361702128
#
# ------------------------------------------------
#
# Rule :frozenset({'Milk', 'Eggs', 'Cheese'})->0.19682539682539682
# Support : 0.19682539682539682
# Confidence : 0.8051948051948052
# Lift : 1.6052934407364787
#
# ...
